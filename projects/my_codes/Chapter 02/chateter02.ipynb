# %% [markdown]
# # chapter 2: Drawing with 2D Vectors
# ## 2.1 Picturing 2D Vectors

# %%
# %load_ext autoreload
# %autoreload 2
from vector_drawing import *

# %%
dino_vectors = [(6,4), (3,1), (1,2), (-1,5), (-2,5), (-3,4), (-4,4),
    (-5,3), (-5,2), (-2,2), (-5,1), (-4,0), (-2,1), (-1,0), (0,-3),
    (-1,-4), (1,-4), (2,-3), (1,-2), (3,-1), (5,1)]
draw(
    Points(*dino_vectors)
)

# %%
draw(
    Points(*dino_vectors),
    Segment((6,4),(3,1))
)

# %%
draw(
    Points(*dino_vectors),
    Polygon(*dino_vectors)
)

# %% [markdown]
# 画f(x) = x^2的图像，x的范围是在[-10, 11]

# %%
draw(
    Points(*[(x,x**2) for x in range(-10,11)]),
    grid=(1,10),
    nice_aspect_ratio=False
)

# %% [markdown]
# # 平面向量算术
# # Plane Vector Arithmetic

# %%
# 向量的加法
def add(v1,v2):
    return (v1[0] + v2[0],v1[1] + v[1])

# %%
# 将dino_vector中的每个向量加上(-1.5,-2.5)这个向量，得到新向量
dino_vectors2 = []
for v in dino_vectors:
    dino_vectors2.append(add((-1.5,-2.5), v))

# %%
draw(
    Points(*dino_vectors, color=blue),
    Polygon(*dino_vectors, color=blue),
    Points(*dino_vectors2, color=red),
    Polygon(*dino_vectors2, color=red),
    
)

# %%
arrows = [Segment(tip,tail,color=black) for (tip,tail) in zip(dino_vectors2, dino_vectors)]

draw(
    Points(*dino_vectors, color=blue),
    Polygon(*dino_vectors,color=blue),
    Points(*dino_vectors2, color=red),
    Polygon(*dino_vectors2,color=red),
    *arrows
)

# %% [markdown]
# # Vector components and lengths
# # 向量的分量和长度

# %%
# 计算向量的长度
from math import sqrt
def length(v):
    return sqrt(v[0]**2 + v[1]**2)

# %% [markdown]
# # Subtraction,displacement,and distance
# # 减法、位移和距离

# %%
# 位移
# v=(-1,3),w=(2,2)
# v-w=(-1-2,3-2) = (-3,1)
# v-w的结果表示，从w点开始，需要向左走3个单位，再向上走1个单位，才能到达v点
#(-3,1)这个向量有时被称为位移
draw(
    Points((2,2),(-1,3)),
    Segment((2,2),(-1,3),color=red)
)

# %% [markdown]
# # 2.2.4 练习

# %% [markdown]
# ## 练习2.6： 对于向量u=(-2,0)、向量v=(1.5,1.5)和向量w=(4,1),
# ## u+v、v+w和u+w的结果是什么？u+v+w的结果是什么?

# %% [markdown]
# ## 练习2.7: 通过将所有向量各自x坐标和y坐标，可以实现任意数量的向量相加。例如，向量和
# ## (1,2) + (2,4) + (3,6) + (4,8)有x分量1+2+3+4=10与y分量2+4+6+8=20,结果为(10,20)。实现新的
# ## add函数，接收任意多个向量作为参数

# %% [markdown]
# ## 练习2.8 实现translate(translation,vectors)，接收一个平移向量和一个向量列表。例如，对于translate((1,1),[(0,0),(0,1),(-3,-3)])，它应该返回[(1,1),(1,2),(-2,-2)]

# %% [markdown]
# ## 练习2.9: 向量之和v+w与w+v结果相同。用坐标形式的向量和定义来解释其原因。同时，用图像来说明为什么这在几何上是成立的。

# %% [markdown]
# ## 练习2.10 在如图2-28所示的三个箭头向量（标为u、v和w）中，哪一对的和对应的箭头最长？哪一对对应的箭头最短。

# %% [markdown]
# ## 2.11： 实现一个处理向量加法的Python函数，显示100个相互不重叠的恐龙图像。这体现了计算机图形学的威力。
# ## 想象一下，手绘2100个坐标对是一件多么乏味的事情！

# %% [markdown]
# ## 练习2.12 对于(3,-2) + (1,1) + (-2,-2)，是x分量还是y分量更长
